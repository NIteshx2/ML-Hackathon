# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
x = [1 , 2 , 3]
y = [4 , 6 , 3]
z = [1 , 9 , 3]
plt.plot(x , y)
plt.plot(x , z)
plt.title("Test Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(["this is y " , "z"] )
plt.show()
