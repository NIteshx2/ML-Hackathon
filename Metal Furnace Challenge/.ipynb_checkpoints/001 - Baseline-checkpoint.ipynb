# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

# %%
os.listdir('./')
# Out:
# ['.ipynb_checkpoints',
#  '001 - Baseline.ipynb',
#  'MetalFurnace-Participants_Data.zip']

# %%
train = pd.read_csv('./Train.csv')
test = pd.read_csv('./Test.csv')
# sample = pd.read_csv('./Sample_Submission.xlsx')

# %%
train
# Out:
#            f0        f1        f2        f3        f4        f5        f6  \
# 0    1.848564 -0.264250 -0.461423  0.409400  1.305455  2.329398  0.370965
# 1   -0.825098 -0.264250  3.032397 -2.442599  1.305455 -0.276144  0.370965
# 2    1.848564 -0.264250 -0.461423  0.409400  1.305455  2.329398  0.370965
# 3    0.511733 -0.264250 -0.461423  0.409400 -0.525726 -0.276144  0.370965
# 4   -0.825098 -0.264250 -0.461423  0.409400 -0.525726 -0.276144  0.370965
# 5   -0.825098 -0.264250 -0.461423  0.409400  1.305455 -0.276144 -2.695676
# 6   -0.825098 -0.264250 -0.461423  0.409400 -0.525726 -0.276144 -2.695676
# 7    0.511733 -0.264250 -0.461423  0.409400 -0.525726 -0.276144  0.370965
# 8   -0.379487  4.550071 -0.461423  0.409400  1.305455 -0.276144  0.370965
# 9    0.066123 -0.264250 -0.461423  0.409400  1.305455  2.665597  0.370965
# 10  -0.825098 -0.264250 -0.461423  0.409400  1.305455 -0.276144 -2.695676
# 11   2.294174 -0.264250 -0.461423  0.409400 -2.356907 -0.276144  0.370965
# ...
